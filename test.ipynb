# %%
import pandas as pd

# %%
ORIGIN_CITY_NAME = pd.read_csv("flight_2019.csv")
df_20 = pd.read_csv("flight_2020.csv")

# %%
df_20[(df_20["ORIGIN_CITY_NAME"] == "New York, NY")& (df_20["PASSENGERS"] == 0.0)]
# Out:
#        PASSENGERS  DISTANCE UNIQUE_CARRIER  \
# 24            0.0     101.0             YX
# 518           0.0     802.0             5X
# 519           0.0      94.0             5X
# 520           0.0    3386.0             5X
# 521           0.0     662.0             5X
# ...           ...       ...            ...
# 42277         0.0    1089.0             WI
# 42278         0.0    3386.0             WI
# 42324         0.0    1089.0             WI
# 42325         0.0    3386.0             WI
# 42338         0.0    3386.0             N8
#
#                                      UNIQUE_CARRIER_NAME  \
# 24                                      Republic Airline
# 518                                United Parcel Service
# 519                                United Parcel Service
# 520                                United Parcel Service
# 521                                United Parcel Service
# ...                                                  ...
# ...

# %%
df_19[(df_19["ORIGIN_CITY_NAME"] == "New York, NY")& (df_19["PASSENGERS"] == 0.0)]
# Out:
#        PASSENGERS  DISTANCE UNIQUE_CARRIER  \
# 86            0.0    3386.0             5Y
# 87            0.0     589.0             5Y
# 88            0.0       0.0             5Y
# 89            0.0     740.0             5Y
# 90            0.0    2548.0             5Y
# ...           ...       ...            ...
# 43598         0.0       7.0            27Q
# 43605         0.0     178.0            27Q
# 43606         0.0      62.0            27Q
# 43607         0.0      11.0            27Q
# 43779         0.0    3386.0             WI
#
#                       UNIQUE_CARRIER_NAME                        CARRIER_NAME  \
# 86                         Atlas Air Inc.                      Atlas Air Inc.
# 87                         Atlas Air Inc.                      Atlas Air Inc.
# 88                         Atlas Air Inc.                      Atlas Air Inc.
# 89                         Atlas Air Inc.                      Atlas Air Inc.
# ...
